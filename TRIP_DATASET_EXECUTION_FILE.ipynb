# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder , OrdinalEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from all_func import *
import pickle 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("taxi_trip_pricing.csv")

# %%
with open("preprocessor.pkl",'rb') as file:
    preprocessor = pickle.load(file)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OHE COLUMNS', OneHotEncoder(),
#                                  ['Day_of_Week', 'Weather', 'Time_of_Day']),
#                                 ('ORDINAL COLUMNS',
#                                  OrdinalEncoder(categories=[['Low', 'Medium',
#                                                              'High']]),
#                                  ['Traffic_Conditions']),
#                                 ('SCALLED_COLUMNS', StandardScaler(),
#                                  ['Trip_Distance_km', 'Base_Fare',
#                                   'Per_Km_Rate', 'Per_Minute_Rate',
#                                   'Trip_Duration_Minutes']),
#                                 ('PASS_thru',
#                                  FunctionTransformer(func=<function same at 0x00000184E5BE1DA0>),
#                                  ['Passenger_Count'])])

# %% [markdown]
# ### MODEL SELECTION

# %%
x = df.drop(columns=['Trip_Price'])

# %%
x
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# 1                 High   Clear        NaN         0.62             0.43
# 2                 High   Clear       2.70         1.21             0.15
# 3                  Low     NaN       3.48         0.51             0.15
# 4                 High   Clear       2.93         0.63             0.32
# ..                 ...     ...        ...          ...              ...
# 995             Medium   Clear       2.39         0.62             0.49
# 996             Medium   Clear       3.12         0.61              NaN
# 997                Low    Rain       2.08         1.78              NaN
# 998                Low   Clear       2.67         0.82             0.17
# 999             Medium   Clear       4.34          NaN             0.23
#
#      Trip_Duration_Minutes
# 0                    53.82
# 1                    40.57
# 2                    37.27
# 3                   116.81
# 4                    22.64
# ..                     ...
# 995                  58.39
# 996                  61.96
# 997                  54.18
# 998                 114.94
# 999                  29.69
#
# [1000 rows x 10 columns]

# %%
y = df['Trip_Price']
y
# Out:
# 0      36.2624
# 1          NaN
# 2      52.9032
# 3      36.4698
# 4      15.6180
#         ...
# 995    34.4049
# 996    62.1295
# 997    33.1236
# 998    61.2090
# 999    45.4437
# Name: Trip_Price, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train , y_test = train_test_split(x, y, test_size=0.2,random_state=30)

# %%
x_train
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 795             43.73     Morning     Weekday              4.0
# 341             24.20   Afternoon     Weekday              1.0
# 217             37.58   Afternoon     Weekday              4.0
# 856              2.79     Evening     Weekday              1.0
# 604              6.91     Morning     Weekday              3.0
# ..                ...         ...         ...              ...
# 500             35.21   Afternoon     Weekend              4.0
# 813               NaN     Morning     Weekday              3.0
# 941             28.15   Afternoon     Weekday              2.0
# 421             39.69   Afternoon     Weekday              3.0
# 805             37.09     Evening     Weekend              4.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 795                Low   Clear       4.64         1.97             0.44
# 341                Low    Snow       2.43         0.75             0.28
# 217                Low    Snow       2.91         1.16             0.47
# 856                Low     NaN       3.62         1.98             0.21
# 604                Low   Clear       2.38         0.89             0.42
# ..                 ...     ...        ...          ...              ...
# 500             Medium   Clear       3.94         0.56             0.39
# 813               High    Snow       2.81         1.04             0.34
# 941               High   Clear       2.06         0.61             0.18
# 421             Medium    Rain       4.90         0.57             0.38
# 805                Low   Clear       3.33         1.87             0.18
#
#      Trip_Duration_Minutes
# 795                 108.76
# 341                 103.17
# 217                  84.52
# 856                 101.08
# 604                  20.57
# ..                     ...
# 500                 110.06
# 813                    NaN
# 941                  17.02
# 421                    NaN
# 805                    NaN
#
# [800 rows x 10 columns]

# %%
x_test
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 923             40.19   Afternoon     Weekday              1.0
# 921             24.88     Morning     Weekend              2.0
# 516             19.45   Afternoon     Weekday              1.0
# 87                NaN         NaN     Weekday              1.0
# 879             11.88   Afternoon     Weekday              2.0
# ..                ...         ...         ...              ...
# 711             30.19     Morning     Weekday              2.0
# 517             40.72     Evening     Weekday              2.0
# 984             36.68     Morning     Weekday              4.0
# 886             32.98     Morning     Weekday              3.0
# 961               NaN   Afternoon     Weekday              2.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 923             Medium   Clear       2.79         1.12             0.10
# 921               High   Clear       3.40         1.54             0.20
# 516               High   Clear       2.40         0.86             0.29
# 87              Medium   Clear       3.41         0.57             0.39
# 879             Medium   Clear       4.67         0.63             0.27
# ..                 ...     ...        ...          ...              ...
# 711             Medium     NaN       2.37         0.76             0.40
# 517               High   Clear       3.64         0.62             0.35
# 984                Low   Clear       2.58         1.11             0.39
# 886               High   Clear       3.67         0.64             0.49
# 961             Medium   Clear       4.06         1.05             0.46
#
#      Trip_Duration_Minutes
# 923                  51.19
# 921                  68.14
# 516                  16.93
# 87                   92.72
# 879                  39.27
# ..                     ...
# 711                 113.33
# 517                  98.49
# 984                 108.41
# 886                 109.94
# 961                   7.26
#
# [200 rows x 10 columns]

# %%
y_train
# Out:
# 795    138.6425
# 341     49.4676
# 217     86.2272
# 856     30.3710
# 604     17.1693
#          ...
# 500     66.5810
# 813     66.8568
# 941     22.2951
# 421     31.0915
# 805     76.4647
# Name: Trip_Price, Length: 800, dtype: float64

# %%
y_test
# Out:
# 923    52.9218
# 921    55.3432
# 516    24.0367
# 87     57.9476
# 879    22.7573
#         ...
# 711    70.6464
# 517    63.3579
# 984    85.5747
# 886    78.6478
# 961    39.4771
# Name: Trip_Price, Length: 200, dtype: float64

# %%
x_train.isnull().sum()
# Out:
# Trip_Distance_km         39
# Time_of_Day              43
# Day_of_Week              43
# Passenger_Count          44
# Traffic_Conditions       42
# Weather                  42
# Base_Fare                36
# Per_Km_Rate              40
# Per_Minute_Rate          45
# Trip_Duration_Minutes    41
# dtype: int64

# %%
x_test.isnull().sum()
# Out:
# Trip_Distance_km         11
# Time_of_Day               7
# Day_of_Week               7
# Passenger_Count           6
# Traffic_Conditions        8
# Weather                   8
# Base_Fare                14
# Per_Km_Rate              10
# Per_Minute_Rate           5
# Trip_Duration_Minutes     9
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# np.int64(40)

# %%
y_test.isnull().sum()
# Out:
# np.int64(9)

# %% [markdown]
# ### USING SIMPLE IMPUTER SEPERATELY TO HANDLE NULL VALUES

# %%
num_null=["Trip_Distance_km", "Passenger_Count", "Base_Fare", "Per_Km_Rate", "Per_Minute_Rate", "Trip_Duration_Minutes"]

cate_null = ["Time_of_Day","Day_of_Week","Traffic_Conditions","Weather"]

# %%
num_imputer = SimpleImputer(strategy="mean")
cat_imputer = SimpleImputer(strategy="most_frequent")

# %% [markdown]
# ### USED SIMPLE IMPUTER FOR X_TRAIN

# %%
x_train[["Time_of_Day","Day_of_Week","Traffic_Conditions","Weather"]] = cat_imputer.fit_transform(x_train[["Time_of_Day","Day_of_Week","Traffic_Conditions","Weather"]])
x_train[["Trip_Distance_km", "Passenger_Count", "Base_Fare", "Per_Km_Rate", "Per_Minute_Rate", "Trip_Duration_Minutes"]] = num_imputer.fit_transform(x_train[["Trip_Distance_km", "Passenger_Count", "Base_Fare", "Per_Km_Rate", "Per_Minute_Rate", "Trip_Duration_Minutes"]])

# %%
x_train.isnull().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Day_of_Week              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# dtype: int64

# %%
x_test[["Time_of_Day","Day_of_Week","Traffic_Conditions","Weather"]] = cat_imputer.transform(x_test[["Time_of_Day","Day_of_Week","Traffic_Conditions","Weather"]])
x_test[["Trip_Distance_km", "Passenger_Count", "Base_Fare", "Per_Km_Rate", "Per_Minute_Rate", "Trip_Duration_Minutes"]] = num_imputer.transform(x_test[["Trip_Distance_km", "Passenger_Count", "Base_Fare", "Per_Km_Rate", "Per_Minute_Rate", "Trip_Duration_Minutes"]])

# %%
x_test.isnull().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Day_of_Week              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# dtype: int64

# %%
y_train_array = np.array(y_train).reshape(-1, 1)
y_train_imputer = SimpleImputer(strategy="mean")
y_train = y_train_imputer.fit_transform(y_train_array).ravel()

# %%
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>

# %%
y_train_series = pd.Series(y_train, name="Trip_Price")
print(type(y_train_series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
y_test = np.array(y_test).reshape(-1,1)
y_test_imputer = SimpleImputer(strategy="mean")
y_test = y_test_imputer.fit_transform(y_test).ravel()

# %%
y_test_series = pd.Series(y_test, name="Trip_Price")

# %% [markdown]
# ### PREPROCESSING THE X TRIAN / Y TRAIN

# %%
x_train_processed = preprocessor.fit_transform(x_train)

# %%
x_test_processed = preprocessor.transform(x_test)

# %% [markdown]
# ### MODEL CREATION

# %%
from sklearn.linear_model import LinearRegression

# %%
Lr = LinearRegression()

# %%
Lr.fit(x_train_processed, y_train_series)
# Out:
# LinearRegression()

# %%
y_predict=Lr.predict(x_test_processed)

# %%
y_test
# Out:
# array([ 52.9218    ,  55.3432    ,  24.0367    ,  57.9476    ,
#         22.7573    ,  49.36      ,  99.8038    ,  26.9202    ,
#         51.031     ,  54.24268422,  45.8975    ,  45.9582    ,
#         14.892     ,  10.2366    , 102.4302    ,  35.0854    ,
#        101.9914    , 123.928     ,  84.873     ,  38.035     ,
#         62.1295    ,  73.5818    ,  14.6127    ,  38.3875    ,
